# %%
a = 12
b = 24
smallest_number = min(a,b)
for i in range(smallest_number,0,-1):
    if a %i == 0 and b % i == 0:
        print("gcd=",i)
        break
# Out:
# gcd= 12

# %%
a = 837837483783783
b = 23432323434
while b != 0:
    a,b = b,a%b
print("gcd=",a)
# Out:
# gcd= 3

# %%
def gcd(a:int,b: int) -> int:
    """function docstring
    """
    if not isinstance(a,int) or not isinstance(b,int):
        raise TypeError("input must be integer")
    if a == 0 and b == 0:
        raise ValueError("gcd is not defined")
    a,b = abs(a),abs(b)
    while b != 0:
        a,b = b,a%b
    return a
#main exceution
if __name__=="__main__":
    a = 50
    b = 60
    try:
        result = gcd(a,b
        print("Gcd is :" r)
    except TypeError as e:
        print(e)
    except ValueError as e:
        print(e)

# %%
gcd(35,76)
# Out:
# 1
