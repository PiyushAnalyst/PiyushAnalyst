# %%
while b != 0:
    a,b = b,a%b
print("gcd=",a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 while b != 0:
#       2     a,b = b,a%b
#       3 print("gcd=",a)
#
# NameError: name 'b' is not defined

# %%
def gcd(a,b):
    if b == 0:
        return a
    return gcd(b,a % b)
gcd()
