# %%
list1 = [100,2,3,4,5,2]
list2 = [4,5,100,200,4,2,3,4,5,6,73,2,2,3,5,4,2,23,4,]
result = []
for item in list1:
    if item in list2 and item not in result:
        result.append(item)
print(result)
# Out:
# [100, 2, 3, 4, 5]

# %%
def intersection(list1:list,list2:list)-> list:
    """ docstring """
    if not  isinstance(list1,list) or not isinstance(list2,list):
        raise TypeError
    if not list1 or not list2:
        raise ValueError
    result = []
    for item in list1:
        if item in list2 and item not in result:
            result.append(item)
    return result
if __name__=="__main__":
    list1 = [100,2,3,4,5,2,3,4,87487]
    list2 = [4,5,100,200,4,2.984726]
    try:
        print(intersection(list1,list2))
    except(TypeError,ValueError)as e:
        print(e)
    except Exception as e:
        print(e)
# Out:
# [100, 4, 5]

# %%
intersection()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 intersection()
#
# TypeError: intersection() missing 2 required positional arguments: 'list1' and 'list2'

# %%
intersection()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 intersection()
#
# TypeError: intersection() missing 2 required positional arguments: 'list1' and 'list2'

# %%
intersection(12,24)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 intersection(12,24)
#
# Cell In[2], line 4, in intersection(list1, list2)
#       2 """ docstring """
#       3 if not  isinstance(list1,list) or not isinstance(list2,list):
# ----> 4     raise TypeError
#       5 if not list1 or not list2:
#       6     raise ValueError
#
# TypeError:

# %%
list1 = [12,323,23,21,2,43]
list2 = [1,2,4,34,54]
intersection(list1,list2)
# Out:
# [2]

# %%
list1 = ["sjhdfagdj"]
list2 = [212,123,21,]
intersection(list1,list2)
# Out:
# []

# %%
intersection("hagdhagdsh","jkhdshg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 intersection("hagdhagdsh","jkhdshg")
#
# Cell In[2], line 4, in intersection(list1, list2)
#       2 """ docstring """
#       3 if not  isinstance(list1,list) or not isinstance(list2,list):
# ----> 4     raise TypeError
#       5 if not list1 or not list2:
#       6     raise ValueError
#
# TypeError:

# %%
list1[1,2,3,4,54,5,6,7,7,5,6,3,2,1,5,6,7,7,8,9,0,23,23,3,2,4,2,24,24,4,23,24,43,3,2,3,2]
list2[12,3,2,42,2]
intersection(list1,list2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 list1[1,2,3,4,54,5,6,7,7,5,6,3,2,1,5,6,7,7,8,9,0,23,23,3,2,4,2,24,24,4,23,24,43,3,2,3,2]
#       2 list2[12,3,2,42,2]
#       3 intersection(list1,list2)
#
# TypeError: list indices must be integers or slices, not tuple
