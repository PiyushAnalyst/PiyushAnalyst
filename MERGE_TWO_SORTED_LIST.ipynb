# %%
list1 = [12,34,56,78,90]
list2 = [4,56,89,90]
merge_list = []
i = j = 0
while i < len(list1) and j < len(list2):
    if list1[i]<=list2[j]:
        merge_list.append(list1[i])
        i = i + 1
    else:
        merge_list.append(list2[j])
        j = j + 1
    # print(merge_list)
while i < len(list1) and j < len(list2):
    if list1[i]<=list2[j]:
        merge_list.append(list1[i])
        i = i + 1
    else:
        merge_list.append(list2[j])
        j = j + 1
print(merge_list)
# Out:
# [4, 12, 34, 56, 56, 78, 89, 90]

# %%
def merge_sorted_list(list1:list,list2:list)->list:
    merge_list = []
    i = j = 0
    while i < len(list1) and j < len(list2):
        if list1[i]<=list2[j]:
            merge_list.append(list1[i])
            i = i + 1
        else:
            merge_list.append(list2[j])
            j = j + 1
        # print(merge_list)
    while i < len(list1) and j < len(list2):
        if list1[i]<=list2[j]:
            merge_list.append(list1[i])
            i = i + 1
        else:
            merge_list.append(list2[j])
            j = j + 1
    print(merge_list)
if __name__=="__main__":
    list1 = [12,34,56,78,90]
    list2 = [4,56,89,90,3,4]
    try:
         print(merge_sorted_list(list1,list2))
    except Exception as e:
        print(e)
# Out:
# [4, 12, 34, 56, 56, 78, 89, 90]
# None
