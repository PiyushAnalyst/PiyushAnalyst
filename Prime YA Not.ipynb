# %%
def is_prime_number(number: int) -> bool:

    if not isinstance(number,int):
        raise TypeError("Input must be an integer")
    if number < 2:
        raise ValueError("Prime number are greater than or equal to 2")
    for i in range(2,int(number**.5)-1):
        if number % i == 0:
            return False
    return True
if __name__ == "__main__":
    try:
        for i in range(5,30):
            if is_prime_number(i):
                print(" it is prime number",i)
    except Exception as e:
        print(e)
# Out:
#  it is prime number 5
#  it is prime number 6
#  it is prime number 7
#  it is prime number 8
#  it is prime number 9
#  it is prime number 10
#  it is prime number 11
#  it is prime number 12
#  it is prime number 13
#  it is prime number 14
#  it is prime number 15
#  it is prime number 17
#  it is prime number 19
#  it is prime number 21
#  it is prime number 23
#  it is prime number 25
#  it is prime number 29

# %%
is_prime_number(78)
# Out:
# False
