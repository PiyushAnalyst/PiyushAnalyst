# %%
text = "apples are good"
def remove_nth_occurence(string:str,char_to_remove:str,n:int)->str:
    occuernce_count = 0
    rsult_character = []
    for current_character in string:
        if current_character == char_to_remove:
            occuernce_count = occuernce_count + 1
            if occuernce_count == 2:
                continue
        rsult_character.append(current_character)
    return "".join(rsult_character)
if __name__=="__main__":
    try:
        text = "apples are good"
        print(remove_nth_occurence(text,"a",2))
    except Exception as e:
        print(e)
# Out:
# apples re good

# %%
remove_nth_occurence(text,"a",2)
# Out:
# 'apples re good'

# %%
text1 = "python is a bad programming"

# %%
remove_nth_occurence(text1,"p",2)
# Out:
# 'python is a bad rogramming'
