# %%
str1 = "piyush"
str2 = ""
for item in str1:
    str2 = item + str2
print(str2)
# Out:
# hsuyip

# %%
def reverse_string(string: str) -> str:
    if not isinstance(string, str):
        raise TypeError("input must be string")

    # check if string is empty
    if string == "":
        raise ValueError("string is empty")

    result = ""

    # reverse logic
    for char in string:
        result = char + result

    return result


if __name__ == "__main__":
    try:
        take_input = "piyush"   # taking input
        result = reverse_string(take_input)
        print("Your reversed string:", result)

    except TypeError as e:
        print("Type Error:", e)

    except ValueError as e:
        print("Value Error:", e)

    except Exception as e:
        print("Unexpected Error:", e)
# Out:
# Your reversed string: hsuyip
