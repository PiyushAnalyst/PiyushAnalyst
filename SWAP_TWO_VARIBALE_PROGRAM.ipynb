# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

# Swapping
a, b = b, a

print("After swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number:  54
# Enter second number:  56
# After swapping:
# a = 56
# b = 54

# %%
def swap_numbers(a, b):
    a = a + b
    b = a - b
    a = a - b
    print("After swapping:")
    print("a =", a)
    print("b =", b)

x = int(input("Enter first number: "))
y = int(input("Enter second number: "))

swap_numbers(x, y)
# Out:
# Enter first number:  764364
# Enter second number:  74676
# After swapping:
# a = 74676
# b = 764364

# %%
def swap_two_numbers(a: int, b: int) -> tuple:
    a = a + b
    b = a - b
    a = a - b
    return a, b


if __name__ == "__main__":
    x = int(input("Enter first number: "))
    y = int(input("Enter second number: "))

    x, y = swap_two_numbers(x, y)

    print("After swapping:")
    print("a =", x)
    print("b =", y)
# Out:
# Enter first number:  7
# Enter second number:  8
# After swapping:
# a = 8
# b = 7

# %%
def swap_two_varible(a:int,b:int)->tuple:
    a = a + b
    b = a - b
    a = a - b
    return a,b 
if __name__=="__main__":
    x = int(input("enter first variable"))
    y = int(input("enter the second variable"))

    x,y =  swap_two_varible(x,y)
    print("after swapping")
    print("a=",x)
    print("b=",y)
# Out:
# enter first variable 4
# enter the second variable 3
# after swapping
# a= 3
# b= 4

# %%
def swap_number(a,b):
    a,b = b,a
    return a ,b
if __name__=="__main__":
    try:
        a = 5
        b = 10
        print("a before swap:" ,a )
        print("b before swap:",b)
        a,b = swap_number(a,b)
        print("a after swap:",a)
        print("b after swap:",b)
    except Exception as e:
        print(e)
# Out:
# a before swap: 5
# b before swap: 10
# a after swap: 10
# b after swap: 5
