# %%
sample_list = [1,2,3,4,5,6,7,10]
for i in range (0,len(sample_list)-1):
    if sample_list[i+1]-sample_list[i] != 1:
        print(sample_list[i]+1)
        break
else:
    print(None)
# Out:
# 8

# %%
def find_missing_number(sample_list: list) -> int:
    
    # validate input
    if not isinstance(sample_list, list):
        raise TypeError("Input must be a list")
        
    if len(sample_list) < 2:
        raise ValueError("At least two numbers required inside list")
        
    if not all(isinstance(item, int) for item in sample_list):
        raise TypeError("All elements of list must be integers")

    # sort list
    sample_list = sorted(sample_list)

    # find missing number
    for i in range(len(sample_list) - 1):
        if sample_list[i+1] - sample_list[i] != 1:
            return sample_list[i] + 1

    return None
if __name__=="__main__":
    try:
        print(find_missing_number(sample_list))
    except (TypeError,ValueError)
