# %%
# Taking input from user (variables)

location = input("Enter Location: ")
employee_name = input("Enter Employee Name: ")
position = input("Enter Position: ")
company_name = input("Enter Company Name: ")
joining_date = input("Enter Joining Date: ")
salary = input("Enter Salary Package: ")
email = input("Enter HR Email: ")
hr_name = input("Enter HR Name: ")
hr_position = input("Enter HR Position: ")

# Offer Letter Format

offer_letter = f"""
{location}

Dear {employee_name},

Subject: Offer of Employment for the position of {position}

We are delighted to extend this formal offer of employment to you for the
position of {position} at {company_name}. Based on your qualifications and the
skills you demonstrated during the recruitment process, we are confident that
you will be a valuable addition to our team.

As discussed, your expected date of joining is {joining_date}. Your total
compensation package will be {salary}, which includes all salary components as
per the company’s policy. Further details regarding your compensation will be
provided in your employment contract.

We expect you to bring your best efforts to help the company achieve its goals,
and we are committed to supporting your professional growth during your time
with us.

Please confirm your acceptance of this offer by sending an email to
{"emaill"} at your earliest convenience. Should you have any queries
regarding this offer, feel free to reach out to us.

We look forward to having you onboard and are excited about the great things we
can accomplish together.

Sincerely,

{hr_name}
{hr_position}
"""

print("\n----- OFFER LETTER -----")
print(offer_letter)
# Out:
# Enter Location:  Noida
# Enter Employee Name:  piyush kumar
# Enter Position:  Data analyst
# Enter Company Name:  DMRG Solutions
# Enter Joining Date:  17\03\2026
# Enter Salary Package:  450000
# Enter HR Email:  riya@dmrgsolution
# Enter HR Name:  Riya Takur
# Enter HR Position:  HR Manager
# ----- OFFER LETTER -----
#
# Noida
#
# Dear piyush kumar,
#
# Subject: Offer of Employment for the position of Data analyst
#
# We are delighted to extend this formal offer of employment to you for the
# position of Data analyst at DMRG Solutions. Based on your qualifications and the
# skills you demonstrated during the recruitment process, we are confident that
# you will be a valuable addition to our team.
#
# As discussed, your expected date of joining is 17\03\2026. Your total
# compensation package will be 450000, which includes all salary components as
# per the company’s policy. Further details regarding your compensation will be
# provided in your employment contract.
#
# We expect you to bring your best efforts to help the company achieve its goals,
# and we are committed to supporting your professional growth during your time
# with us.
#
# Please confirm your acceptance of this offer by sending an email to
# emaill at your earliest convenience. Should you have any queries
# regarding this offer, feel free to reach out to us.
#
# We look forward to having you onboard and are excited about the great things we
# can accomplish together.
#
# Sincerely,
#
# Riya Takur
# HR Manager
