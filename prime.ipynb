# %%
number = 17
for i in range(2, int(number**0.5) + 1):
    print(i)
    if number % i == 0:
        print("not a prime number")
        break
else:
    print("prime number")
# Out:
# 2
# 3
# 4
# prime number

# %%
def is_prime_number(number: int) -> bool:
    # validate input must be int
    if not isinstance(number, int):
        raise TypeError("input must be int")

    # check the number < 2
    if number < 2:
        return False   # better than raising error

    # loop logic
    for i in range(2, int(number**0.5) + 1):
        if number % i == 0:
            return False   # not prime

    return True   #  prime


if __name__ == "__main__":
    try:
        # Taking input from user
        user_input = input("Enter the number: ")

        # convert the number into int
        number = int(user_input)

        # Calling the function
        if is_prime_number(number):
            print("Prime number")
        else:
            print("Not a prime number")

    except TypeError as e:
        print(e)

    except ValueError as error:
        print(error)

    except Exception as e:
        print(e)
# Out:
# Enter the number:  7
# Prime number

# %%
def is_prime_number(number: int) -> bool:

    if not isinstance(number,int):
        raise TypeError("Input must be an integer")
    if number < 2:
        raise ValueError("Prime number are greater than or equal to 2")
    for i in range(2,int(number**.5)-1):
        if number % i == 0:
            return False
            break
    else:
        return True
if __name__ == "__main__":
    try:
        prime_number = []
        lower_limit = input("Enter lower limit : ")
        upper_limit = input("Enter upper limit : ")
        if not lower_limit.strip().isdigit():
            raise TypeError("Lower limit mudt be a valid integer (no decimal or letter).")
        if not upper_limit.strip().isdigit():
            raise TypeError("Lower limit mudt be a valid integer (no decimal or letter).")
        lower_limit= int(lower_limit)
        upper_limit= int(upper_limit)
        for i in range(lower_limit,upper_limit):
            if is_prime_number(i):
                print(f"{i} prime number")
                prime_number.append(i)
        print(prime_number)
    except (TypeError) as e:
        print(e)
    except ValueError as error:
        print(error)
    except Exception as e:
        print(e)
# Out:
# Enter lower limit :  100
# Enter upper limit :  200
# 101 prime number
# 103 prime number
# 107 prime number
# 109 prime number
# 113 prime number
# 121 prime number
# 127 prime number
# 131 prime number
# 137 prime number
# 139 prime number
# 143 prime number
# 149 prime number
# 151 prime number
# 157 prime number
# 163 prime number
# 167 prime number
# 169 prime number
# 173 prime number
# 179 prime number
# 181 prime number
# 191 prime number
# 193 prime number
# 197 prime number
# 199 prime number
# [101, 103, 107, 109, 113, 121, 127, 131, 137, 139, 143, 149, 151, 157, 163, 167, 169, 173, 179, 181, 191, 193, 197, 199]

# %%
is_prime_number(7)
# Out:
# True

# %%
is_prime_number(373767)
# Out:
# False

# %%
number = 7878
for i in range(2,int(number**0.5) + 1):
    print(i)
    if number % i == 0:
        print("not a prime number")
        break
else:
    print("prime number")
# Out:
# 2
# not a prime number

# %%
is_prime_number(7)
# Out:
# True
