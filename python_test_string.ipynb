# %%
# How do you concatenate two string in python
str1 = "Hello"
str2 = "World"

result = str1 + str2
result
# Out:
# 'HelloWorld'

# %%
# what is the difference between the +operator and join () method for concatenting strings
#The + opearor combined the two string and the joint opeator also join two values
str1 = "hello"
str2 = "python"
result = str1 + str2
result
# Out:
# 'hellopython'

# %%
# Q4
#For finding the length in python basically we use
str = ("hello world")
len("hello world")
# Out:
# 11

# %%
# Q5
# we can use captilise
name = " this is python class"
str.capitalize()
# Out:
# 'This is python class'

# %%
# Q6
WE USE LOWE
str.lower("HELLO WORLD")
# Out:
# 'hello world'

# %%
# Q9
str = "this is first python program"
str.startswith("this")
# Out:
# True

# %%
# Q10
str = "hello world"
str.endswith("world")
# Out:
# True

# %%
# Q10
str = "hello world"
str.endswith("hello")
# Out:
# False

# %%
# Q12
str = "hello world"
str.index("e")
# Out:
# 1

# %%
# Q13
str = "hello world wwwwwww"
str.count("w")
# Out:
# 8

# %%
# Q14
str = "hello world"
str.isalpha()
# Out:
# False

# %%
# Q14
str = "hello python"
str.isalpha()
# Out:
# False

# %%
# Q15
str = "67"
str.isdigit()
# Out:
# True

# %%
words = ["Hello", "World"]
result = " ".join(words)
result
# Out:
# 'Hello World'

# %%
# Q18
string = "HelloWorld"

result = string[:5] + " " + string[5:]
result
# Out:
# 'Hello World'

# %%
# Q17
string = "Python"
result = string[::-1]
result
# Out:
# 'nohtyP'

# %%
# Q18
name = "Piyush"
age = 22

result = "My name is {} and I am {} years old".format(name, age)
result
# Out:
# 'My name is Piyush and I am 22 years old'

# %%
# Q20
string = "hello world"
result = string.replace("l", "")
result
# Out:
# 'heo word'
